# %% [markdown]
# ## This notebook may be used to reproduce the top left panel in Fig 3.

# %%
import matplotlib
import matplotlib.ticker as ticker
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
EPEP1 = pd.read_csv('./DataFilesFromMatCont/EP_EP1_Bif_beta_dm7p5_r1.csv',header=None)
EPEP1 = np.asarray(EPEP1)
EPEP2 = pd.read_csv('./DataFilesFromMatCont/EP_EP2_Bif_beta_dm7p5_r1.csv',header=None)
EPEP2 = np.asarray(EPEP2)

BPEP1 = pd.read_csv('./DataFilesFromMatCont/BP_EP1_Bif_beta_dm7p5_r1.csv',header=None)
BPEP1 = np.asarray(BPEP1)
BPEP2 = pd.read_csv('./DataFilesFromMatCont/BP_EP2_Bif_beta_dm7p5_r1.csv',header=None)
BPEP2 = np.asarray(BPEP2)
BPEP3 = pd.read_csv('./DataFilesFromMatCont/BP_EP3_Bif_beta_dm7p5_r1.csv',header=None)
BPEP3 = np.asarray(BPEP3)
BPEP4 = pd.read_csv('./DataFilesFromMatCont/BP_EP4_Bif_beta_dm7p5_r1.csv',header=None)
BPEP4 = np.asarray(BPEP4)
BPEP5 = pd.read_csv('./DataFilesFromMatCont/BP_EP5_Bif_beta_dm7p5_r1.csv',header=None)
BPEP5 = np.asarray(BPEP5)
BPEP6 = pd.read_csv('./DataFilesFromMatCont/BP_EP6_Bif_beta_dm7p5_r1.csv',header=None)
BPEP6 = np.asarray(BPEP6)

HLC1 = pd.read_csv('./DataFilesFromMatCont/H_LC1_Bif_beta_dm7p5_r1.csv',header=None)
HLC1 = np.asarray(HLC1)
HLC2 = pd.read_csv('./DataFilesFromMatCont/H_LC2_Bif_beta_dm7p5_r1.csv',header=None)
HLC2 = np.asarray(HLC2)
HLC3 = pd.read_csv('./DataFilesFromMatCont/H_LC3_Bif_beta_dm7p5_r1.csv',header=None)
HLC3 = np.asarray(HLC3)

# %%
for kk in [0,1]:
    EPEP1[kk][EPEP1[kk]<0]=0
    EPEP2[kk][EPEP2[kk]<0]=0
    BPEP1[kk][BPEP1[kk]<0]=0
    BPEP2[kk][BPEP2[kk]<0]=0
    BPEP3[kk][BPEP3[kk]<0]=0
    BPEP4[kk][BPEP4[kk]<0]=0
    BPEP5[kk][BPEP5[kk]<0]=0
    BPEP6[kk][BPEP6[kk]<0]=0
#for jj in range(len(HLC1)-1):
#    HLC1[jj][HLC1[jj]<0]=0
#for jj in range(len(HLC2)-1):
#    HLC2[jj][HLC2[jj]<0]=0
#for jj in range(len(HLC3)-1):
#    HLC3[jj][HLC3[jj]<0]=0

# %%
HLC_Asym_beta = []
HLC_Asym_maxAmp = []
HLC_Asym_minAmp = []
with open('asymOrbitAmp_beta.csv', 'r') as infile:
    infile.readline
    for line in infile:
        if not line.startswith('#'): # I usually use the first line in a data file to give some info using "#" 
            HLC_Asym_beta.append(float(line.split(',')[0]))  # "split" separates all objects in a line when delimeter "," occurs
            HLC_Asym_maxAmp.append(float(line.split(',')[1]))  # all objects in the data file are strings
            HLC_Asym_minAmp.append(float(line.split(',')[2]))  # here these are converted using float(....)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()

ax.plot(EPEP2[3], EPEP2[0]-EPEP2[1], lw=4, c='k', ls='-')
ax.plot(EPEP1[3][:33], EPEP1[0][:33]-EPEP1[1][:33], lw=4, c='k', ls='-')
ax.plot(EPEP1[3][33:108], EPEP1[0][33:108]-EPEP1[1][33:108], lw=5, c='k', ls='--')
ax.plot(EPEP1[3][108:123], EPEP1[0][108:123]-EPEP1[1][108:123], lw=4, c='k', ls='-')
ax.plot(EPEP1[3][123:145], EPEP1[0][123:145]-EPEP1[1][123:145], lw=3, c='k', ls='--')
ax.plot(EPEP1[3][145:], EPEP1[0][145:]-EPEP1[1][145:], lw=3, c='k', ls='--')

ax.plot(BPEP1[3][:49], BPEP1[0][:49]-BPEP1[1][:49], lw=4, c='b', ls='--')
ax.plot(BPEP1[3][49:90], BPEP1[0][49:90]-BPEP1[1][49:90], lw=4, c='b', ls='-')
ax.plot(BPEP1[3][90:150], BPEP1[0][90:150]-BPEP1[1][90:150], lw=4, c='b', ls='--')
ax.plot(BPEP1[3][150:204], BPEP1[0][150:204]-BPEP1[1][150:204], lw=3, c='g', ls='--')
ax.plot(BPEP1[3][204:252], BPEP1[0][204:252]-BPEP1[1][204:252], lw=4, c='g', ls='-')
ax.plot(BPEP1[3][252:298], BPEP1[0][252:298]-BPEP1[1][252:298], lw=3, c='g', ls='--')

#ax.plot(BPEP2[3][:], BPEP2[0][:]-BPEP2[1][:], lw=4, c='b', ls='-')
#ax.plot(BPEP2[3][:], BPEP2[0][:]-BPEP2[1][:], lw=4, c='b', ls='--')
#ax.plot(BPEP3[3][:], BPEP3[0][:]-BPEP3[1][:], lw=4, c='b', ls='--')
ax.plot(BPEP4[3][:13], BPEP4[0][:13]-BPEP4[1][:13], lw=4, c='b', ls='-')
ax.plot(BPEP4[3][13:], BPEP4[0][13:]-BPEP4[1][13:], lw=3, c='b', ls='--')
ax.plot(BPEP5[3][:14], BPEP5[0][:14]-BPEP5[1][:14], lw=4, c='g', ls='-')
ax.plot(BPEP5[3][14:], BPEP5[0][14:]-BPEP5[1][14:], lw=3, c='g', ls='--')
#ax.plot(BPEP6[3][:], BPEP6[0][:]-BPEP6[1][:], lw=4, c='r', ls='--')

MaxValLC1 = np.max(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
MinValLC1 = np.min(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
ax.plot(HLC1[-1], MaxValLC1, lw=7, c='r', ls=':')
MaxValLC2 = np.max(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
MinValLC2 = np.min(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
ax.plot(HLC2[-1], MaxValLC2, lw=5, c='deepskyblue', ls=':')
ax.plot(HLC2[-1], MinValLC2, lw=5, c='deepskyblue', ls=':')
MaxValLC3 = np.max(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
MinValLC3 = np.min(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
ax.plot(HLC3[-1], MaxValLC3, lw=5, c='limegreen', ls=':')
ax.plot(HLC3[-1], MinValLC3, lw=5, c='limegreen', ls=':')

ax.plot(HLC_Asym_beta, HLC_Asym_maxAmp, lw=5, c='red', ls='-')
ax.plot(HLC_Asym_beta, HLC_Asym_minAmp, lw=5, c='red', ls='-')

#plt.xlabel(r'inhibition strength $\beta$', fontsize=28)
plt.ylabel(r'motivation $x_1-x_2$', fontsize=28)
#for tick in ax.xaxis.get_major_ticks():
#    tick.label.set_fontsize(22) 
#for tick in ax.yaxis.get_major_ticks():
#    tick.label.set_fontsize(22)
ax.tick_params(labelbottom='off',labeltop='on', pad=6)
plt.setp( ax.xaxis.get_majorticklabels(), rotation=0, fontsize=22)
plt.setp( ax.yaxis.get_majorticklabels(), rotation=0, fontsize=22)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.tick_params('both', length=8, width=2, which='major')
ax.tick_params('both', length=6, width=1, which='minor')

ax.plot([0.2,0.45],[4.5,4.5], c='grey', ls='-', lw=5)
ax.plot([0.2,0.45],[3.8,3.8], c='grey', ls='--', lw=5)
ax.plot([0.2,0.45],[3.1,3.1], c='grey', ls=':', lw=6)
ax.annotate(r'stable',
            xy=(0.55, 4.5), xycoords='data', fontsize=20, 
            horizontalalignment='left', verticalalignment='center')
ax.annotate(r'unstable',
            xy=(0.55, 3.8), xycoords='data', fontsize=20, 
            horizontalalignment='left', verticalalignment='center')
ax.annotate(r'periodic',
            xy=(0.55, 3.1), xycoords='data', fontsize=20, 
            horizontalalignment='left', verticalalignment='center')


LP1x = 0.5745
LP1y = 0.9277-0.3394
LP2x = LP1x
LP2y = -LP1y
LP3x = 2.4193
LP3y = 0.8340#+2.0867
LP4x = LP3x
LP4y = -LP3y
LP5x = 0.5748
LP5y = 0
BP1x = 2.4193
BP1y = 0
BP2x = 0.5748
BP2y = 0
BP3x = 1.2814
BP3y = 0
H1x = 1.8625
H1y = 0.2887-0.0682
H2x = H1x
H2y = -H1y
H3x = 3.3606
H3y = 0
ax.plot([LP1x,LP2x,LP3x,LP4x,LP5x,BP1x,BP2x,BP3x,H1x,H2x,H3x],[LP1y,LP2y,LP3y,LP4y,LP5y,BP1y,BP2y,BP3y,H1y,H2y,H3y], 
        'ok', ms=12)


'''
LP1x = 0.5745
LP1y = 0.9277-0.3394
LP2x = LP1x
LP2y = -LP1y
#ax.plot([LP1x],[LP1y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP1x-0.02, LP1y+0.3), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')
#ax.plot([LP2x],[LP2y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP2x-0.03, LP2y-0.4), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')

LP3x = 2.4193
LP3y = 0.8340#+2.0867
LP4x = LP3x
LP4y = -LP3y
#ax.plot([LP3x],[LP3y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP3x-0.01, LP3y+0.35), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')
#ax.plot([LP4x],[LP4y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP4x-0.01, LP4y-0.45), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')

LP5x = 0.5748
LP5y = 0
#ax.plot([LP5x],[LP5y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP5x, LP5y-0.32), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')

BP1x = 2.4193
BP1y = 0
ax.plot([BP1x],[BP1y], 'ok', ms=10)
ax.annotate(r'BP',
            xy=(BP1x, BP1y+0.2), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')

BP2x = 0.5748
BP2y = 0
ax.plot([BP2x],[BP2y], 'ok', ms=10)
ax.annotate(r'BP',
            xy=(BP2x, BP2y+0.22), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')

BP3x = 1.2814
BP3y = 0
ax.plot([BP3x],[BP3y], 'ok', ms=10)
ax.annotate(r'BP',
            xy=(BP3x, BP3y+0.25), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')

H1x = 1.8625
H1y = 0.2887-0.0682
ax.plot([H1x],[H1y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H1x, H1y+0.4), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center')
H2x = H1x
H2y = -H1y
ax.plot([H2x],[H2y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H2x, H2y-0.5), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center')
H3x = 3.3606
H3y = 0
ax.plot([H3x],[H3y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H3x+0.02, H3y+0.22), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')
'''
#plt.legend(loc='upper left', fontsize=22)

#ax.annotate(r'inflection point', xy=(7.5, 0.5), xytext=(8.4, 0.3), fontsize=22,
#            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03),
#            horizontalalignment='left', verticalalignment='bottom')
#ax.annotate(r'at $\xi = b = 7.5$',
#            xy=(8.8, 0.22), xycoords='data', fontsize=22, horizontalalignment='center')
#fig.set_tight_layout(True)

plt.xlim(0.025,5)
plt.ylim(-1,1)

plt.tight_layout();
