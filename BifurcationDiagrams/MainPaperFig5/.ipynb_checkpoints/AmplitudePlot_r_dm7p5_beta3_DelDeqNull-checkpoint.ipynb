# %% [markdown]
# ## This notebook may be used to reproduce the bottom-right panel in Fig 5 (Fig.5D).

# %%
import matplotlib
import matplotlib.ticker as ticker
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# read data
Amp1 = pd.read_csv('./Amplitudes_r_X1start_0.0.csv',header=0)
Amp1 = np.asarray(Amp1)
Amp2 = pd.read_csv('./Amplitudes_r_X1start_0.2.csv',header=0)
Amp2 = np.asarray(Amp2)
Amp3 = pd.read_csv('./Amplitudes_r_X1start_0.4.csv',header=0)
Amp3 = np.asarray(Amp3)
Amp4 = pd.read_csv('./Amplitudes_r_X1start_1.0.csv',header=0)
Amp4 = np.asarray(Amp4)
Amp5 = pd.read_csv('./Amplitudes_r_X1start_5.0_X2start_5.0.csv',header=0)
Amp5 = np.asarray(Amp5)
Amp6 = pd.read_csv('./Amplitudes_r_X1start_0.1_X2start_0.1_Ystart_0.3.csv',header=0)
Amp6 = np.asarray(Amp6)
Amp7 = pd.read_csv('./Amplitudes_r_X1start_0.2_X2start_0.2_Ystart_0.4.csv',header=0)
Amp7 = np.asarray(Amp7)
Amp8 = pd.read_csv('./Amplitudes_r_X1start_0.3_X2start_0.3_Ystart_0.5.csv',header=0)
Amp8 = np.asarray(Amp8)

# %%
# sort data
Amp1_r=np.asarray([Amp1[jj][0] for jj in range(len(Amp1))])
Amp1_max=np.asarray([Amp1[jj][1] for jj in range(len(Amp1))])
Amp1_min=np.asarray([Amp1[jj][2] for jj in range(len(Amp1))])
Amp1_x1=np.asarray([Amp1[jj][3] for jj in range(len(Amp1))])
Amp1_x2=np.asarray([Amp1[jj][4] for jj in range(len(Amp1))])
Amp1_y=np.asarray([Amp1[jj][5] for jj in range(len(Amp1))])

Amp2_r=np.asarray([Amp2[jj][0] for jj in range(len(Amp2))])
Amp2_max=np.asarray([Amp2[jj][1] for jj in range(len(Amp2))])
Amp2_min=np.asarray([Amp2[jj][2] for jj in range(len(Amp2))])
Amp2_x1=np.asarray([Amp2[jj][3] for jj in range(len(Amp2))])
Amp2_x2=np.asarray([Amp2[jj][4] for jj in range(len(Amp2))])
Amp2_y=np.asarray([Amp2[jj][5] for jj in range(len(Amp2))])

Amp3_r=np.asarray([Amp3[jj][0] for jj in range(len(Amp3))])
Amp3_max=np.asarray([Amp3[jj][1] for jj in range(len(Amp3))])
Amp3_min=np.asarray([Amp3[jj][2] for jj in range(len(Amp3))])
Amp3_x1=np.asarray([Amp3[jj][3] for jj in range(len(Amp3))])
Amp3_x2=np.asarray([Amp3[jj][4] for jj in range(len(Amp3))])
Amp3_y=np.asarray([Amp3[jj][5] for jj in range(len(Amp3))])

Amp4_r=np.asarray([Amp4[jj][0] for jj in range(len(Amp4))])
Amp4_max=np.asarray([Amp4[jj][1] for jj in range(len(Amp4))])
Amp4_min=np.asarray([Amp4[jj][2] for jj in range(len(Amp4))])
Amp4_x1=np.asarray([Amp4[jj][3] for jj in range(len(Amp4))])
Amp4_x2=np.asarray([Amp4[jj][4] for jj in range(len(Amp4))])
Amp4_y=np.asarray([Amp4[jj][5] for jj in range(len(Amp4))])

Amp5_r=np.asarray([Amp5[jj][0] for jj in range(len(Amp5))])
Amp5_max=np.asarray([Amp5[jj][1] for jj in range(len(Amp5))])
Amp5_min=np.asarray([Amp5[jj][2] for jj in range(len(Amp5))])
Amp5_x1=np.asarray([Amp5[jj][3] for jj in range(len(Amp5))])
Amp5_x2=np.asarray([Amp5[jj][4] for jj in range(len(Amp5))])
Amp5_y=np.asarray([Amp5[jj][5] for jj in range(len(Amp5))])

Amp6_r=np.asarray([Amp6[jj][0] for jj in range(len(Amp6))])
Amp6_max=np.asarray([Amp6[jj][1] for jj in range(len(Amp6))])
Amp6_min=np.asarray([Amp6[jj][2] for jj in range(len(Amp6))])
Amp6_x1=np.asarray([Amp6[jj][3] for jj in range(len(Amp6))])
Amp6_x2=np.asarray([Amp6[jj][4] for jj in range(len(Amp6))])
Amp6_y=np.asarray([Amp6[jj][5] for jj in range(len(Amp6))])

Amp7_r=np.asarray([Amp7[jj][0] for jj in range(len(Amp7))])
Amp7_max=np.asarray([Amp7[jj][1] for jj in range(len(Amp7))])
Amp7_min=np.asarray([Amp7[jj][2] for jj in range(len(Amp7))])
Amp7_x1=np.asarray([Amp7[jj][3] for jj in range(len(Amp7))])
Amp7_x2=np.asarray([Amp7[jj][4] for jj in range(len(Amp7))])
Amp7_y=np.asarray([Amp7[jj][5] for jj in range(len(Amp7))])

Amp8_r=np.asarray([Amp8[jj][0] for jj in range(len(Amp8))])
Amp8_max=np.asarray([Amp8[jj][1] for jj in range(len(Amp8))])
Amp8_min=np.asarray([Amp8[jj][2] for jj in range(len(Amp8))])
Amp8_x1=np.asarray([Amp8[jj][3] for jj in range(len(Amp8))])
Amp8_x2=np.asarray([Amp8[jj][4] for jj in range(len(Amp8))])
Amp8_y=np.asarray([Amp8[jj][5] for jj in range(len(Amp8))])

# %%
# test plot
figTest = plt.figure(figsize=(8,6))
ax = plt.axes()
ax.plot(Amp1_r, Amp1_max, lw=4, c='r', ls='-')
#ax.plot(Amp2_r, Amp2_max, lw=4, c='g', ls='-')
#ax.plot(Amp3_r, Amp3_max, lw=4, c='b', ls='-')
#ax.plot(Amp4_r, Amp4_max, lw=4, c='y', ls='-')
ax.plot(Amp6_r, Amp6_max, lw=4, c='b', ls='-')
ax.plot(Amp7_r, Amp7_max, lw=4, c='y', ls='-')
ax.plot(Amp8_r, Amp8_max, lw=4, c='y', ls='-')
ax.plot(Amp5_r, Amp5_max, lw=4, c='c', ls='-')
ax.plot(Amp1_r, Amp1_min, lw=4, c='r', ls='-')
#ax.plot(Amp2_r, Amp2_min, lw=4, c='g', ls='-')
#ax.plot(Amp3_r, Amp3_min, lw=4, c='b', ls='-')
#ax.plot(Amp4_r, Amp4_min, lw=4, c='y', ls='-')
#ax.plot(Amp5_r, Amp5_min, lw=4, c='c', ls='-')
ax.plot(Amp6_r, Amp6_min, lw=4, c='y', ls='-')
ax.plot(Amp7_r, Amp7_min, lw=4, c='c', ls='-')
ax.plot(Amp8_r, Amp8_min, lw=4, c='c', ls='-')

# %%
# test plot
figTest = plt.figure(figsize=(8,6))
ax = plt.axes()
ax.plot(Amp1_r, Amp1_x1-Amp1_x2, lw=4, c='r', ls='-')
ax.plot(Amp2_r, Amp2_x1-Amp2_x2, lw=4, c='g', ls='-')
#ax.plot(Amp3_r, Amp3_x1-Amp3_x2, lw=4, c='b', ls='-')
#ax.plot(Amp4_r, Amp4_x1-Amp4_x2, lw=4, c='y', ls='-')
ax.plot(Amp5_r, Amp5_x1-Amp5_x2, lw=4, c='c', ls='-')
ax.plot(Amp6_r, Amp6_x1-Amp6_x2, lw=4, c='c', ls='-')
ax.plot(Amp7_r, Amp7_x1-Amp7_x2, lw=4, c='c', ls='-')
ax.plot(Amp8_r, Amp8_x1-Amp8_x2, lw=4, c='c', ls='-')
plt.ylim(0,0.3)
# Out:
# (0, 0.3)

# %%
# test plot
figTest = plt.figure(figsize=(8,6))
ax = plt.axes()
#ax.plot(Amp1_r, Amp1_x1, lw=4, c='r', ls='-')
#ax.plot(Amp1_r, Amp1_x2, lw=4, c='r', ls='--')
#ax.plot(Amp2_r, Amp2_x1-Amp2_x2, lw=4, c='g', ls='-')
#ax.plot(Amp3_r, Amp3_x1-Amp3_x2, lw=4, c='b', ls='-')
#ax.plot(Amp4_r, Amp4_x1-Amp4_x2, lw=4, c='y', ls='-')
#ax.plot(Amp5_r, Amp5_x1, lw=4, c='c', ls='-')
#ax.plot(Amp5_r, Amp5_x2, lw=4, c='c', ls='--')
ax.plot(Amp6_r, Amp6_x1, lw=4, c='r', ls='-')
ax.plot(Amp6_r, Amp6_x2, lw=4, c='r', ls='--')
ax.plot(Amp7_r, Amp7_x1, lw=4, c='g', ls='-')
ax.plot(Amp7_r, Amp7_x2, lw=4, c='g', ls='--')
ax.plot(Amp8_r, Amp8_x1, lw=4, c='0.5', ls='-')
ax.plot(Amp8_r, Amp8_x2, lw=4, c='0.5', ls='--')
plt.ylim(0,5)
# Out:
# (0, 5)

# %%
# test plot
figTest2 = plt.figure(figsize=(8,6))
ax = plt.axes()
rA=108
rB=178
ax.plot(Amp8_r[rA:rB], Amp8_x1[rA:rB], lw=4, c='0.5', ls='-')
print(Amp8_r[rA])
print(Amp8_r[rB-1])
# Out:
# 1.08
# 1.77

# %%
# plot Fig.5D
fig1 = plt.figure(figsize=(8,7))
ax = plt.axes()
change1=73
change2=113

LP1x = 3.8845
LP1y = 0.3542+2.3950
LP2x = LP1x
LP2y = -LP1y
LP3x = 1.0061
LP3y = 0.8575#+2.8125
LP4x = LP3x
LP4y = -LP3y
LP5x = 1.0061
LP5y = 0
BP1x = 1.0061
BP1y = 0
BP2x = 0.5610
BP2y = 0
#BP3x = 1.2814
#BP3y = 0
#ax.plot([BP3x],[BP3y], 'ok', ms=10)
#ax.annotate(r'BP',
#            xy=(BP3x, BP3y+0.18), xycoords='data', fontsize=16, 
#            horizontalalignment='right', verticalalignment='center')
H1x = 0.7185
H1y = 0.2706-0.0548
H2x = H1x
H2y = -H1y
H3x = 1.0811
H3y = 0
LPC1x = Amp1_r[change2-1]#1.039
LPC1y = Amp1_max[change2-1]
LPC1xb = Amp1_r[change2-1]
LPC1yb = -Amp1_max[change2-1]
LPC1xc = Amp1_r[change2-1]
LPC1yc = Amp1_min[change2-1]
LPC1xd = Amp1_r[change2-1]
LPC1yd = -Amp1_min[change2-1]
rA=108
rB=178
LPC2x = Amp8_r[rB-1]
LPC2y = 0

ax.plot(Amp1_r[0:change1+1], Amp1_x1[0:change1+1]-Amp1_x2[0:change1+1], lw=6, c='k', ls='-')
ax.plot(Amp1_r[change1:change2], Amp1_max[change1:change2], lw=6, c='k', ls='--')
ax.plot(Amp1_r[change1:change2], Amp1_min[change1:change2], lw=6, c='k', ls='--')
#ax.plot(Amp1_r[change2-1:change2+1], [Amp1_max[change2-1],0.027], lw=4, c='k', ls='--')
##ax.plot(Amp4_r[101:252], Amp4_x1[101:252]-Amp4_x2[101:252], lw=4, c='k', ls='-')
ax.plot(Amp5_r[101:252], Amp5_x1[101:252]-Amp5_x2[101:252], lw=6, c='k', ls='-')

ax.plot(Amp1_r[0:change1+1], -Amp1_x1[0:change1+1]+Amp1_x2[0:change1+1], lw=6, c='k', ls='-')
ax.plot(Amp1_r[change1:change2], -Amp1_max[change1:change2], lw=6, c='k', ls='--')
ax.plot(Amp1_r[change1:change2], -Amp1_min[change1:change2], lw=6, c='k', ls='--')
#ax.plot(Amp1_r[change2-1:change2+1], [-Amp1_max[change2-1],-0.027], lw=4, c='k', ls='--')
ax.plot([Amp8_r[rA],Amp8_r[rB-1]], [0,0], lw=12, c='k', ls='--')

ax.plot([LP1x,LP2x,LP3x,LP4x,LP5x,BP1x,BP2x,H1x,H2x,H3x],[LP1y,LP2y,LP3y,LP4y,LP5y,BP1y,BP2y,H1y,H2y,H3y], 
        'ok', ms=17, mfc='grey',mew=2,mec='k')
ax.plot([LPC1x,LPC1xb,LPC1xc,LPC1xd,LPC2x],[LPC1y,LPC1yb,LPC1yc,LPC1yd,LPC2y], 
        'Dk', ms=14, mfc='grey',mew=2,mec='k')


#plt.xlabel(r'E/I-ratio $r$', fontsize=28)
#plt.ylabel(r'motivation $x_1-x_2$', fontsize=28)
ax.set_ylabel(r'motivations $x_1^s-x_2^s$', fontsize=34, labelpad=48)
ax.yaxis.set_label_position('right')
plt.setp( ax.yaxis.get_label(), rotation=-90)
ax.set_xlabel(r'E/I-ratio $r$', fontsize=34, labelpad=6)
plt.setp( ax.xaxis.get_label(), rotation=180)
#plt.setp(labels, rotation=90)
ax.tick_params(labelbottom='on',labeltop='off', labelleft='off', labelright='on', pad=8)
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, fontsize=26)
plt.setp( ax.yaxis.get_majorticklabels(), rotation=-90, fontsize=26)

ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.3))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.tick_params('both', length=8, width=2, which='major')
ax.tick_params('both', length=6, width=1, which='minor')

#ax.plot([0.2,0.45],[12,12], c='grey', ls='-', lw=5)
#ax.plot([0.2,0.45],[10.5,10.5], c='grey', ls='--', lw=5)
#ax.plot([0.2,0.45],[9,9], c='grey', ls=':', lw=6)
ax.plot([2.32,2.32],[-0.28,-0.22], c='k', ls='-', lw=6)
ax.plot([2.18,2.18],[-0.28,-0.22], c='k', ls='--', lw=6)
#ax.plot([0.6,0.6],[2.5,4.5], c='grey', ls=':', lw=6)
ax.annotate(r'stable',
            xy=(2.32, -0.21), xycoords='data', fontsize=27, 
            horizontalalignment='center', verticalalignment='top',rotation=-90)
#ax.annotate(r'unstable',
#            xy=(0.45, 4.8), xycoords='data', fontsize=20, 
#            horizontalalignment='center', verticalalignment='top', rotation=-90)
ax.annotate(r'periodic',
            xy=(2.18, -0.21), xycoords='data', fontsize=27, 
            horizontalalignment='center', verticalalignment='top', rotation=-90)

plt.xlim(0.025,2.5)
plt.ylim(0.3,-0.3);

plt.tight_layout();

# %%
# save Fig.5D
fig1.savefig("Fig5_BottomRight.pdf")
