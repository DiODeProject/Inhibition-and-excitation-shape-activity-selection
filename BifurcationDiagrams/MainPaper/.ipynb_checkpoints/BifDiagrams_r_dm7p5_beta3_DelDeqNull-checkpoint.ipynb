# %% [markdown]
# ## This notebook may be used to reproduce the bottom right panel in Fig 3.

# %%
import matplotlib
import matplotlib.ticker as ticker
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
EPEP1 = pd.read_csv('./DataFilesFromMatCont/EP_EP1_Bif_r_dm7p5_beta3.csv',header=None)
EPEP1 = np.asarray(EPEP1)
EPEP2 = pd.read_csv('./DataFilesFromMatCont/EP_EP2_Bif_r_dm7p5_beta3.csv',header=None)
EPEP2 = np.asarray(EPEP2)

BPEP1 = pd.read_csv('./DataFilesFromMatCont/BP_EP1_Bif_r_dm7p5_beta3.csv',header=None)
BPEP1 = np.asarray(BPEP1)
BPEP2 = pd.read_csv('./DataFilesFromMatCont/BP_EP2_Bif_r_dm7p5_beta3.csv',header=None)
BPEP2 = np.asarray(BPEP2)
BPEP3 = pd.read_csv('./DataFilesFromMatCont/BP_EP3_Bif_r_dm7p5_beta3.csv',header=None)
BPEP3 = np.asarray(BPEP3)
BPEP4 = pd.read_csv('./DataFilesFromMatCont/BP_EP4_Bif_r_dm7p5_beta3.csv',header=None)
BPEP4 = np.asarray(BPEP4)

HLC1 = pd.read_csv('./DataFilesFromMatCont/H_LC1_Bif_r_dm7p5_beta3.csv',header=None)
HLC1 = np.asarray(HLC1)
HLC2 = pd.read_csv('./DataFilesFromMatCont/H_LC2_Bif_r_dm7p5_beta3.csv',header=None)
HLC2 = np.asarray(HLC2)
HLC3 = pd.read_csv('./DataFilesFromMatCont/H_LC3_Bif_r_dm7p5_beta3.csv',header=None)
HLC3 = np.asarray(HLC3)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()

ax.plot(EPEP1[3], EPEP1[0]-EPEP1[1], lw=4, c='k', ls='-')
ax.plot(EPEP2[3][:10], EPEP2[0][:10]-EPEP2[1][:10], lw=4, c='k', ls='-')
ax.plot(EPEP2[3][10:16], EPEP2[0][10:16]-EPEP2[1][10:16], lw=5, c='k', ls='--')
ax.plot(EPEP2[3][16:86], EPEP2[0][16:86]-EPEP2[1][16:86], lw=5, c='k', ls='--')
ax.plot(EPEP2[3][86:203], EPEP2[0][86:203]-EPEP2[1][86:203], lw=5, c='k', ls='--')
ax.plot(EPEP2[3][203:], EPEP2[0][203:]-EPEP2[1][203:], lw=4, c='k', ls='-')

#ax.plot(BPEP1[3][:], BPEP1[0][:]-BPEP1[1][:], lw=4, c='b', ls='--')
#ax.plot(BPEP2[3][:], BPEP2[0][:]-BPEP2[1][:], lw=4, c='g', ls='--')

ax.plot(BPEP3[3][:8], BPEP3[0][:8]-BPEP3[1][:8], lw=4, c='b', ls='-')
ax.plot(BPEP3[3][8:52], BPEP3[0][8:52]-BPEP3[1][8:52], lw=4, c='b', ls='--')
ax.plot(BPEP3[3][52:100], BPEP3[0][52:100]-BPEP3[1][52:100], lw=4, c='b', ls='--')
ax.plot(BPEP3[3][100:], BPEP3[0][100:]-BPEP3[1][100:], lw=4, c='b', ls='-')

ax.plot(BPEP4[3][:9], BPEP4[0][:9]-BPEP4[1][:9], lw=4, c='g', ls='-')
ax.plot(BPEP4[3][9:53], BPEP4[0][9:53]-BPEP4[1][9:53], lw=4, c='g', ls='--')
ax.plot(BPEP4[3][53:100], BPEP4[0][53:100]-BPEP4[1][53:100], lw=4, c='g', ls='--')
ax.plot(BPEP4[3][100:], BPEP4[0][100:]-BPEP4[1][100:], lw=4, c='g', ls='-')

MaxValLC1 = np.max(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
MinValLC1 = np.min(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
ax.plot(HLC1[-1], MaxValLC1, lw=7, c='r', ls=':')
MaxValLC2 = np.max(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
MinValLC2 = np.min(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
ax.plot(HLC2[-1], MaxValLC2, lw=5, c='deepskyblue', ls=':')
ax.plot(HLC2[-1], MinValLC2, lw=5, c='deepskyblue', ls=':')
MaxValLC3 = np.max(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
MinValLC3 = np.min(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
ax.plot(HLC3[-1], MaxValLC3, lw=5, c='limegreen', ls=':')
ax.plot(HLC3[-1], MinValLC3, lw=5, c='limegreen', ls=':')

plt.xlim(0.025,2.5)
plt.ylim(10,-10)

#plt.xlabel(r'E/I-ratio $r$', fontsize=28)
#plt.ylabel(r'motivation $x_1-x_2$', fontsize=28)
ax.set_ylabel(r'motivation $x_1-x_2$', fontsize=28, labelpad=46)
ax.yaxis.set_label_position('right')
plt.setp( ax.yaxis.get_label(), rotation=-90, fontsize=28)
#plt.setp(labels, rotation=90)

#for tick in ax.xaxis.get_major_ticks():
#    tick.label.set_fontsize(22)
#for tick in ax.yaxis.get_major_ticks():
#    tick.label.set_fontsize(22)

ax.tick_params(labelbottom='on',labeltop='off', labelleft='off', labelright='on', pad=6)
plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, fontsize=22)
plt.setp( ax.yaxis.get_majorticklabels(), rotation=-90, fontsize=22)

ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(5))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(1))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.tick_params('both', length=8, width=2, which='major')
ax.tick_params('both', length=6, width=1, which='minor')

#ax.plot([0.2,0.45],[12,12], c='grey', ls='-', lw=5)
#ax.plot([0.2,0.45],[10.5,10.5], c='grey', ls='--', lw=5)
#ax.plot([0.2,0.45],[9,9], c='grey', ls=':', lw=6)
ax.plot([0.3,0.3],[2.5,4.5], c='grey', ls='-', lw=5)
ax.plot([0.45,0.45],[2.5,4.5], c='grey', ls='--', lw=5)
ax.plot([0.6,0.6],[2.5,4.5], c='grey', ls=':', lw=6)
ax.annotate(r'stable',
            xy=(0.3, 4.8), xycoords='data', fontsize=20, 
            horizontalalignment='center', verticalalignment='top',rotation=-90)
ax.annotate(r'unstable',
            xy=(0.45, 4.8), xycoords='data', fontsize=20, 
            horizontalalignment='center', verticalalignment='top', rotation=-90)
ax.annotate(r'periodic',
            xy=(0.6, 4.8), xycoords='data', fontsize=20, 
            horizontalalignment='center', verticalalignment='top', rotation=-90)

LP1x = 3.8845
LP1y = 0.3542+2.3950
LP2x = LP1x
LP2y = -LP1y
ax.plot([LP1x],[LP1y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP1x+0.05, LP1y), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center', rotation=-90)
ax.plot([LP2x],[LP2y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP2x+0.05, LP2y), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center', rotation=-90)

LP3x = 1.0061
LP3y = 0.8575+2.8125
LP4x = LP3x
LP4y = -LP3y
ax.plot([LP3x],[LP3y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP3x-0.05, LP3y), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center', rotation=-90)
ax.plot([LP4x],[LP4y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP4x-0.05, LP4y), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center', rotation=-90)

LP5x = 1.0061
LP5y = 0
ax.plot([LP5x],[LP5y], 'ok', ms=10)
ax.annotate(r'LP',
            xytext=(LP5x+0.07, LP5y+2), xycoords='data', fontsize=16, xy=(LP5x, LP5y),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.001, width=2, headlength=4, headwidth=6),
            horizontalalignment='left', verticalalignment='center', rotation=-90)

BP1x = 1.0061
BP1y = 0
ax.plot([BP1x],[BP1y], 'ok', ms=10)
ax.annotate(r'BP',
            xy=(BP1x+0.15, BP1y+2), xycoords='data', fontsize=16,
            horizontalalignment='left', verticalalignment='center', rotation=-90)

BP2x = 0.5610
BP2y = 0
ax.plot([BP2x],[BP2y], 'ok', ms=10)
ax.annotate(r'BP',
            xy=(BP2x, BP2y+1.), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center',  rotation=-90)

#BP3x = 1.2814
#BP3y = 0
#ax.plot([BP3x],[BP3y], 'ok', ms=10)
#ax.annotate(r'BP',
#            xy=(BP3x, BP3y+0.18), xycoords='data', fontsize=16, 
#            horizontalalignment='right', verticalalignment='center')

H1x = 0.7185
H1y = 0.2706-0.0548
ax.plot([H1x],[H1y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H1x-0.05, H1y+0.8), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center', rotation=-90)
H2x = H1x
H2y = -H1y
ax.plot([H2x],[H2y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H2x-0.05, H2y-0.7), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center', rotation=-90)
H3x = 1.0811
H3y = 0
ax.plot([H3x],[H3y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H3x-0.03, H3y-0.95), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center', rotation=-90)

#plt.legend(loc='upper left', fontsize=22)

#ax.annotate(r'inflection point', xy=(7.5, 0.5), xytext=(8.4, 0.3), fontsize=22,
#            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03),
#            horizontalalignment='left', verticalalignment='bottom')
#ax.annotate(r'at $\xi = b = 7.5$',
#            xy=(8.8, 0.22), xycoords='data', fontsize=22, horizontalalignment='center')
#fig.set_tight_layout(True)

plt.tight_layout();
