# %%
import matplotlib
import matplotlib.ticker as ticker
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
EPEP1 = pd.read_csv('./DataFilesFromMatCont/EP_EP1_Bif_dm_deld0.csv',header=None)
EPEP1 = np.asarray(EPEP1)
EPEP2 = pd.read_csv('./DataFilesFromMatCont/EP_EP2_Bif_dm_deld0.csv',header=None)
EPEP2 = np.asarray(EPEP2)

BPEP1 = pd.read_csv('./DataFilesFromMatCont/BP_EP1_Bif_dm_deld0.csv',header=None)
BPEP1 = np.asarray(BPEP1)
BPEP2 = pd.read_csv('./DataFilesFromMatCont/BP_EP2_Bif_dm_deld0.csv',header=None)
BPEP2 = np.asarray(BPEP2)

HLC1 = pd.read_csv('./DataFilesFromMatCont/H_LC1_Bif_dm_deld0.csv',header=None)
HLC1 = np.asarray(HLC1)
HLC2 = pd.read_csv('./DataFilesFromMatCont/H_LC2_Bif_dm_deld0.csv',header=None)
HLC2 = np.asarray(HLC2)
HLC3 = pd.read_csv('./DataFilesFromMatCont/H_LC3_Bif_dm_deld0.csv',header=None)
HLC3 = np.asarray(HLC3)

# %%
# This cell reproduces the bottom panel in Fig S2(a)

fig = plt.figure(figsize=(8,6))
ax = plt.axes()

ax.plot(EPEP1[3], EPEP1[0]-EPEP1[1], lw=3, c='k', ls='-')
ax.plot(EPEP2[3][0:182], EPEP2[0][0:182]-EPEP2[1][0:182], lw=3, c='k', ls='-')
ax.plot(EPEP2[3][182:494], EPEP2[0][182:494]-EPEP2[1][182:494], lw=5, c='k', ls='--')

#ax.plot(EPEP3[3][0:126], EPEP3[0][0:126]-EPEP3[1][0:126], lw=4, c='g', ls='-')
#ax.plot(EPEP3[3][126:], EPEP3[0][126:]-EPEP3[1][126:], lw=4, c='g', ls='--')
#ax.plot(EPEP6[3][0:126], EPEP6[0][0:126]-EPEP6[1][0:126], lw=4, c='b', ls='-')
#ax.plot(EPEP6[3][126:], EPEP6[0][126:]-EPEP6[1][126:], lw=4, c='b', ls='--')

ax.plot(BPEP1[3][:7], BPEP1[0][:7]-BPEP1[1][:7], lw=4, c='b', ls='--')
ax.plot(BPEP1[3][7:10], BPEP1[0][7:10]-BPEP1[1][7:10], lw=4, c='b', ls='-')
ax.plot(BPEP1[3][10:416], BPEP1[0][10:416]-BPEP1[1][10:416], lw=4, c='b', ls='--')
ax.plot(BPEP1[3][416:754], BPEP1[0][416:754]-BPEP1[1][416:754], lw=4, c='b', ls='-')
ax.plot(BPEP1[3][754:1092], BPEP1[0][754:1092]-BPEP1[1][754:1092], lw=4, c='b', ls='--')

ax.plot(BPEP1[3][1092:1433], BPEP1[0][1092:1433]-BPEP1[1][1092:1433], lw=4, c='g', ls='--')
ax.plot(BPEP1[3][1433:1771], BPEP1[0][1433:1771]-BPEP1[1][1433:1771], lw=4, c='g', ls='-')
ax.plot(BPEP2[3][:8], BPEP2[0][:8]-BPEP2[1][:8], lw=4, c='g', ls='--')
ax.plot(BPEP2[3][8:11], BPEP2[0][8:11]-BPEP2[1][8:11], lw=4, c='g', ls='-')
ax.plot(BPEP2[3][11:417], BPEP2[0][11:417]-BPEP2[1][11:417], lw=4, c='g', ls='--')
#ax.plot(BPEP2[3][417:599], BPEP2[0][417:599]-BPEP2[1][417:599], lw=4, c='b', ls='-')

MaxValLC1 = np.max(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
MinValLC1 = np.min(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
ax.plot(HLC1[-1], MaxValLC1, lw=6, c='deepskyblue', ls=':')
ax.plot(HLC1[-1], MinValLC1, lw=6, c='deepskyblue', ls=':')
MaxValLC2 = np.max(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
MinValLC2 = np.min(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
ax.plot(HLC2[-1], MaxValLC2, lw=5, c='limegreen', ls=':')
ax.plot(HLC2[-1], MinValLC2, lw=5, c='limegreen', ls=':')
MaxValLC3 = np.max(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
MinValLC3 = np.min(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
ax.plot(HLC3[-1], MaxValLC3, lw=7, c='red', ls=':')
ax.plot(HLC3[-1], MinValLC3, lw=7, c='red', ls=':')

plt.xlim(0,25)
plt.ylim(-5.5,5.5)

plt.xlabel(r'mean deficit $d_m$', fontsize=28)
plt.ylabel(r'motivation $x_1-x_2$', fontsize=28)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(22) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(22)

ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.5))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.tick_params('both', length=8, width=2, which='major')
ax.tick_params('both', length=6, width=1, which='minor')

ax.plot([17.5,19],[3.3,3.3], c='grey', ls='-', lw=5)
ax.plot([17.5,19],[2.6,2.6], c='grey', ls='--', lw=5)
ax.plot([17.5,19],[1.9,1.9], c='grey', ls=':', lw=6)
ax.annotate(r'stable',
            xy=(19.5, 3.3), xycoords='data', fontsize=20, 
            horizontalalignment='left', verticalalignment='center')
ax.annotate(r'unstable',
            xy=(19.5, 2.6), xycoords='data', fontsize=20, 
            horizontalalignment='left', verticalalignment='center')
ax.annotate(r'periodic',
            xy=(19.5, 1.9), xycoords='data', fontsize=20, 
            horizontalalignment='left', verticalalignment='center')


LP1x = 17.2547
LP1y = 0
ax.plot([LP1x],[LP1y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP1x+0.05, LP1y+0.4), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')



H3x = 2.4958
H3y = 0
ax.plot([H3x],[H3y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H3x, H3y+0.2), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')
   
LP4x = 13.4752
LP4y = -0.6920-0.3688
ax.plot([LP4x],[LP4y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP4x+0.3, LP4y), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')

LP5x = LP4x
LP5y = -LP4y
ax.plot([LP5x],[LP5y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP5x+0.3, LP5y), xycoords='data', fontsize=16, 
            horizontalalignment='left', verticalalignment='center')

LP6x = 20.0867
LP6y = 0.1129-5.0108
ax.plot([LP6x],[LP6y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP6x-0.1, LP6y+0.4), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center')

LP7x = LP6x
LP7y = -LP6y
ax.plot([LP7x],[LP7y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP7x-0.1, LP7y-0.45), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center')    

    


Homocl1x = 3.4933
Homocl1y = 0
ax.annotate(r'homoclinic bif.',
            xy=(Homocl1x, Homocl1y), xycoords='data', fontsize=20, 
            xytext=(6, -1.1),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03, width=2, headwidth=5),
            horizontalalignment='center', verticalalignment='top')

LPC1x = 3.7080
LPC1y = 0
ax.annotate(r'LPC',
            xy=(LPC1x, LPC1y), xycoords='data', fontsize=20, 
            xytext=(4.5, 2),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03, width=2, headwidth=5),
            horizontalalignment='center', verticalalignment='center')


#plt.legend(loc='upper left', fontsize=22)

#ax.annotate(r'inflection point', xy=(7.5, 0.5), xytext=(8.4, 0.3), fontsize=22,
#            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03),
#            horizontalalignment='left', verticalalignment='bottom')
#ax.annotate(r'at $\xi = b = 7.5$',
#            xy=(8.8, 0.22), xycoords='data', fontsize=22, horizontalalignment='center')
#fig.set_tight_layout(True)

plt.tight_layout();

# %%
# This cell reproduces the top panel in Fig S2(a)

fig = plt.figure(figsize=(8,6))
ax = plt.axes()

ax.plot(EPEP1[3], EPEP1[0]-EPEP1[1], lw=3, c='k', ls='-')
ax.plot(EPEP2[3][0:182], EPEP2[0][0:182]-EPEP2[1][0:182], lw=3, c='k', ls='-')
ax.plot(EPEP2[3][182:494], EPEP2[0][182:494]-EPEP2[1][182:494], lw=5, c='k', ls='--')

#ax.plot(EPEP3[3][0:126], EPEP3[0][0:126]-EPEP3[1][0:126], lw=4, c='g', ls='-')
#ax.plot(EPEP3[3][126:], EPEP3[0][126:]-EPEP3[1][126:], lw=4, c='g', ls='--')
#ax.plot(EPEP6[3][0:126], EPEP6[0][0:126]-EPEP6[1][0:126], lw=4, c='b', ls='-')
#ax.plot(EPEP6[3][126:], EPEP6[0][126:]-EPEP6[1][126:], lw=4, c='b', ls='--')

ax.plot(BPEP1[3][:7], BPEP1[0][:7]-BPEP1[1][:7], lw=4, c='b', ls='--')
ax.plot(BPEP1[3][7:10], BPEP1[0][7:10]-BPEP1[1][7:10], lw=4, c='b', ls='-')
ax.plot(BPEP1[3][10:416], BPEP1[0][10:416]-BPEP1[1][10:416], lw=4, c='b', ls='--')
#ax.plot(BPEP1[3][416:754], BPEP1[0][416:754]-BPEP1[1][416:754], lw=4, c='g', ls='-')
#ax.plot(BPEP1[3][754:1092], BPEP1[0][754:1092]-BPEP1[1][754:1092], lw=4, c='g', ls='--')

#ax.plot(BPEP1[3][1092:1433], BPEP1[0][1092:1433]-BPEP1[1][1092:1433], lw=4, c='b', ls='--')
#ax.plot(BPEP1[3][1433:1771], BPEP1[0][1433:1771]-BPEP1[1][1433:1771], lw=4, c='b', ls='-')
ax.plot(BPEP2[3][:8], BPEP2[0][:8]-BPEP2[1][:8], lw=4, c='g', ls='--')
ax.plot(BPEP2[3][8:11], BPEP2[0][8:11]-BPEP2[1][8:11], lw=4, c='g', ls='-')
ax.plot(BPEP2[3][11:417], BPEP2[0][11:417]-BPEP2[1][11:417], lw=4, c='g', ls='--')
#ax.plot(BPEP2[3][417:599], BPEP2[0][417:599]-BPEP2[1][417:599], lw=4, c='b', ls='-')

MaxValLC1 = np.max(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
MinValLC1 = np.min(HLC1[0:-3:3]-HLC1[1:-2:3],axis=0)
ax.plot(HLC1[-1], MaxValLC1, lw=6, c='deepskyblue', ls=':')
ax.plot(HLC1[-1], MinValLC1, lw=6, c='deepskyblue', ls=':')
MaxValLC2 = np.max(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
MinValLC2 = np.min(HLC2[0:-3:3]-HLC2[1:-2:3],axis=0)
ax.plot(HLC2[-1], MaxValLC2, lw=5, c='limegreen', ls=':')
ax.plot(HLC2[-1], MinValLC2, lw=5, c='limegreen', ls=':')
MaxValLC3 = np.max(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
MinValLC3 = np.min(HLC3[0:-3:3]-HLC3[1:-2:3],axis=0)
ax.plot(HLC3[-1], MaxValLC3, lw=5, c='red', ls=':')
ax.plot(HLC3[-1], MinValLC3, lw=5, c='red', ls=':')

plt.xlim(0.6,1.5)
plt.ylim(-3.1,3.1)

plt.xlabel(r'mean deficit $d_m$', fontsize=28)
plt.ylabel(r'motivation $x_1-x_2$', fontsize=28)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(22) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(22)

ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.05))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.5))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.tick_params('both', length=8, width=2, which='major')
ax.tick_params('both', length=6, width=1, which='minor')

LP2x = 0.6572
LP2y = 0.0190-0.1860
ax.plot([LP2x],[LP2y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP2x-0.01, LP2y-0.1), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')

LP3x = LP2x
LP3y = -LP2y
ax.plot([LP3x],[LP3y], 'ok', ms=10)
ax.annotate(r'LP',
            xy=(LP3x-0.01, LP3y+0.1), xycoords='data', fontsize=16, 
            horizontalalignment='right', verticalalignment='center')


BP1x = 0.6919
BP1y = 0
ax.plot([BP1x],[BP1y], 'ok', ms=10)
ax.annotate(r'BP',
            xy=(BP1x, BP1y), xycoords='data', fontsize=16, 
            xytext=(BP1x+0.07, BP1x+0.05),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03, width=2, headwidth=5),
            horizontalalignment='left', verticalalignment='center')



H1x = 0.6817
H1y = 0.2073+0.0193
ax.plot([H1x],[H1y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H1x, H1y+0.2), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center')


H2x = H1x
H2y = -H1y
ax.plot([H2x],[H2y], 'ok', ms=10)
ax.annotate(r'H',
            xy=(H2x, H2y-0.25), xycoords='data', fontsize=16, 
            horizontalalignment='center', verticalalignment='center')

ax.plot([1.4464,1.4464], [3.1,-3.1], ls='-',lw=3, c='k')
ax.annotate(r'homoclinic bifurcation',
            xy=(1.4464, -1), xycoords='data', fontsize=20, 
            xytext=(1, -2),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03, width=2, headwidth=5),
            horizontalalignment='center', verticalalignment='center')

ax.annotate(r'min/max amplitudes of orbit',
            xy=(1.3, 0.8), xycoords='data', fontsize=20, 
            xytext=(1, 2),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03, width=2, headwidth=5),
            horizontalalignment='center', verticalalignment='center')
ax.annotate(r'',
            xy=(1.3, 0.05), xycoords='data', fontsize=20, 
            xytext=(1, 1.8),
            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03, width=2, headwidth=5),
            horizontalalignment='center', verticalalignment='center')

#plt.legend(loc='upper left', fontsize=22)

#ax.annotate(r'inflection point', xy=(7.5, 0.5), xytext=(8.4, 0.3), fontsize=22,
#            arrowprops=dict(facecolor='grey', edgecolor='grey', shrink=0.03),
#            horizontalalignment='left', verticalalignment='bottom')
#ax.annotate(r'at $\xi = b = 7.5$',
#            xy=(8.8, 0.22), xycoords='data', fontsize=22, horizontalalignment='center')
#fig.set_tight_layout(True)

plt.tight_layout();
